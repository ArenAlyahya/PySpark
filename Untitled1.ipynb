# %%
install_requires=[
        'pyspark=={site.SPARK_VERSION}'
    ]
import sys 
from pyspark import SparkContext, SparkConf
from pyspark.ml.feature import StopWordsRemover
from pyspark.sql import SQLContext
from pyspark.sql.functions import regexp_replace, trim, col, lower 
from pyspark.ml.feature import Tokenizer

# %%
conf = SparkConf().setAppName("app")
# create Spark context with necessary configuration
sc = SparkContext.getOrCreate(conf=conf)

# %%
spark_session = SparkSession.builder \
    .config(conf=conf) \
    .getOrCreate() \

# %%
path = '/Data/*/*.txt'
rdd = sc.wholeTextFiles(path)

# %%
stop_words = ['i','me','my','myself','we','our','ours','ourselves',
              'you','your','yours','yourself','yourselves','he','him',
              'his','himself','she','her','hers','herself','it','its',
              'itself','they','them','their','theirs','themselves',
              'what','which','who','whom','this','that','these','those',
              'am','is','are','was','were','be','been','being','have',
              'has','had','having','do','does','did','doing','a','an',
              'the','and','but','if','or','because','as','until','while',
              'of','at','by','for','with','about','against','between',
              'into','through','during','before','after','above','below',
              'to','from','up','down','in','out','on','off','over','under',
              'again','further','then','once','here','there','when','where',
              'why','how','all','any','both','each','few','more','most',
              'other','some','such','no','nor','not','only','own','same',
              'so','than','too','very','can','will','just','don','should','now']

# %%
def make_document_index(raw_status):
    status = raw_status.flatMap(lambda x : x).filter(lambda x: x.lower() not in stopWords)
    doc_index = status.zipWithIndex()
    doc_index = doc_index.map(lambda y: (y[1], y[0])).collectAsMap()
    return doc_index

def inverted_index(documents):
    #Invert to (status_id, terms[]) and then flatMapValues in order to get (status_id, term)
    documents = documents.map(lambda x: (x[1],x[0])).flatMapValues(lambda x: x)
    #Undo to (term, status_id) and reduce to get (term, status_ids[])
    documents = documents.map(lambda x: (x[1],[x[0]])).reduceByKey(lambda a,b: a+b)
    print("inverted index sucessfully created")
    return documents

# %%
#messages = filtered_final.select("filtered1","status_id").rdd
# Conduct MapReduce and write the output to folder
raw_status = sc.textFile("data")

status_inverted_index = make_document_index(raw_status)
status_inverted_index = inverted_index(status_inverted_index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-29588b65decb> in <module>
#       1 # Conduct MapReduce and write the output to folder
#       2 raw_status = sc.textFile("data")
# ----> 3 messages = raw_status.select().rdd
#       4
#       5
#
# AttributeError: 'RDD' object has no attribute 'select'

# %%
#output = rdd.flatMap(lambda file,contents: contents.lower().split())\
#            .filter(lambda x: x.lower() not in stopWords)\
 #           .map(lambda file,word: (word,file)).reduceByKey(lambda a,b: a+b)
#   
    
output = rdd.flatMap(lambda file,contents: contents.lower().split(" ")).filter(lambda x: x.lower() not in stopWords)\
           .map(lambda file,word: (word,file))
            
#output.top(10)

# %%
output = output.reduceByKey(lambda a, b: a + b)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-78-43590a67aaf0> in <module>
# ----> 1 output = output.reduceByKey(lambda a, b: a + b)
#
# /usr/local/lib/python3.7/site-packages/pyspark/rdd.py in reduceByKey(self, func, numPartitions, partitionFunc)
#    1623         [('a', 2), ('b', 1)]
#    1624         """
# -> 1625         return self.combineByKey(lambda x: x, func, func, numPartitions, partitionFunc)
#    1626
#    1627     def reduceByKeyLocally(self, func):
#
# /usr/local/lib/python3.7/site-packages/pyspark/rdd.py in combineByKey(self, createCombiner, mergeValue, mergeCombiners, numPartitions, partitionFunc)
#    1851         """
#    1852         if numPartitions is None:
# -> 1853             numPartitions = self._defaultReducePartitions()
#    1854
#    1855         serializer = self.ctx.serializer
#
# ...

# %%
output=inverted_index(w)
#.reduceByKey(lambda a, b: a + b)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-79-fd8a52e29730> in <module>
# ----> 1 output=inverted_index(w)
#       2 #.reduceByKey(lambda a, b: a + b)
#
# <ipython-input-74-e5445e53e163> in inverted_index(documents)
#       9     documents = documents.map(lambda x: (x[1],x[0])).flatMapValues(lambda x: x)
#      10     #Undo to (term, status_id) and reduce to get (term, status_ids[])
# ---> 11     documents = documents.map(lambda x: (x[1],[x[0]])).reduceByKey(lambda a,b: a+b)
#      12     print("inverted index sucessfully created")
#      13     return documents
#
# /usr/local/lib/python3.7/site-packages/pyspark/rdd.py in reduceByKey(self, func, numPartitions, partitionFunc)
#    1623         [('a', 2), ('b', 1)]
#    1624         """
# -> 1625         return self.combineByKey(lambda x: x, func, func, numPartitions, partitionFunc)
#    1626
# ...

# %%
path = '/Data/Tolstoy/*.txt'
rdd = sc.wholeTextFiles(path)



output = rdd.flatMap(lambda file,contents: contents.lower().split())\
            .filter(lambda x: x.lower() not in stopWords)\
            .map(lambda file,word: (word,file)).reduceByKey(lambda a,b: a+b)
#   
    
#output = rdd.flatMap(lambda file,contents: contents.lower().split(" ")).filter(lambda x: x.lower() not in stopWords)\
 #           .map(lambda file,word: (word,file))
            
output.top(10)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-80-05ef66e6223d> in <module>
#       6 output = rdd.flatMap(lambda file,contents: contents.lower().split())\
#       7             .filter(lambda x: x.lower() not in stopWords)\
# ----> 8             .map(lambda file,word: (word,file)).reduceByKey(lambda a,b: a+b)
#       9 #
#      10
#
# /usr/local/lib/python3.7/site-packages/pyspark/rdd.py in reduceByKey(self, func, numPartitions, partitionFunc)
#    1623         [('a', 2), ('b', 1)]
#    1624         """
# -> 1625         return self.combineByKey(lambda x: x, func, func, numPartitions, partitionFunc)
#    1626
#    1627     def reduceByKeyLocally(self, func):
#
# /usr/local/lib/python3.7/site-packages/pyspark/rdd.py in combineByKey(self, createCombiner, mergeValue, mergeCombiners, numPartitions, partitionFunc)
#    1851         """
# ...

# %%
# Conduct MapReduce and write the output to folder
#path = '/Data/Tolstoy/*.txt'
#rdd = sc.wholeTextFiles(path)
wordCounts = sc.textFile("/Data/Tolstoy/anna_karenhina.txt").flatMap(lambda line: line.split(" "))\
.map( lambda word: (word , 1)).reduceByKey(lambda a, b: a + b )
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-99-1d7003f761fe> in <module>
#       3 #rdd = sc.wholeTextFiles(path)
#       4 wordCounts = sc.textFile("/Data/Tolstoy/anna_karenhina.txt").flatMap(lambda line: line.split(" "))\
# ----> 5 .map( lambda word: (word , 1)).reduceByKey(lambda a, b: a + b )
#
# /usr/local/lib/python3.7/site-packages/pyspark/rdd.py in reduceByKey(self, func, numPartitions, partitionFunc)
#    1623         [('a', 2), ('b', 1)]
#    1624         """
# -> 1625         return self.combineByKey(lambda x: x, func, func, numPartitions, partitionFunc)
#    1626
#    1627     def reduceByKeyLocally(self, func):
#
# /usr/local/lib/python3.7/site-packages/pyspark/rdd.py in combineByKey(self, createCombiner, mergeValue, mergeCombiners, numPartitions, partitionFunc)
#    1851         """
#    1852         if numPartitions is None:
# ...
